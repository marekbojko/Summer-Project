# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML

# %%
from evolving_comm_network import *

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(-0.5, 1.5), ylim=(-0.5, 1.5))
particles_d, = ax.plot([], [], 'bo', ms=3)
particles_c, = ax.plot([], [], 'go', ms=3)
#parents, = ax.plot([], [], 'ro', ms=4)

# initialization function: plot the background of each frame
def init():
    particles_c.set_data([], [])
    particles_d.set_data([], [])
    #parents.set_data([], [])
    return particles_c,particles_d

# animation function.  This is called sequentially
def animate(i):
    global locs,loc_c,loc_d
    x_c = [z[0] for z in loc_c[i]]
    y_c = [z[1] for z in loc_c[i]]
    particles_c.set_data(x_c,y_c)
    x_d = [z[0] for z in loc_d[i]]
    y_d = [z[1] for z in loc_d[i]]
    particles_d.set_data(x_d,y_d)
    return particles_c,particles_d

# %% [markdown]
# ### Simulation 1
# - Placed randomly in space
# - Probability of C: 0.2
# - Noise to location of offsprings: N(0,0.01)

# %%
PD1 = Simulation_PD(40, 200, bernoulli_arms, discounted_thompson, 50)
locs,loc_c,loc_d = PD1.plot_data_mult_gen()

# %%
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=50, interval=100, blit=True)

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Simulation 2
# - Initially placed into 4 distinct groups
# - Probability of C: 0
# - Noise to location of offsprings: N(0,0.01)

# %%
PD2 = Simulation_PD(40, 200, bernoulli_arms, discounted_thompson, 50, True,-1)
locs,loc_c,loc_d = PD2.plot_data_mult_gen()
# Out:
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight

# %%
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=50, interval=100, blit=True)

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### Simulation 3
# - Initially placed into 4 distinct groups
# - Probability of C: 0
# - Noise to location of offsprings: N(0,0.01)

# %%
PD3 = Simulation_PD(40, 200, bernoulli_arms, discounted_thompson, 25, True,-1)
locs,loc_c,loc_d = PD3.plot_data_mult_gen()
# Out:
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight

# %%
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=25, interval=300, blit=True)

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### Simulation 4
# - Initially placed into 4 distinct groups
# - Probability of C: 0
# - Noise to location of offsprings: None

# %%
PD4 = Simulation_PD(40, 200, bernoulli_arms, discounted_thompson, 25, True,-1)
locs,loc_c,loc_d = PD4.plot_data_mult_gen(0)
# Out:
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight

# %%
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=25, interval=300, blit=True)

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### Simulation 5
# - Initially placed randomly
# - Probability of C: 0
# - Noise to location of offsprings: 0

# %%
PD5 = Simulation_PD(40, 200, bernoulli_arms, discounted_thompson, 25, False,-1)
locs,loc_c,loc_d = PD5.plot_data_mult_gen(0)
# Out:
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight
# /home/pgrad2/2265960b/project/Summer-Project/Thompson/graph_measures.py:42: RuntimeWarning: invalid value encountered in double_scalars
#   return recip_weight/total_weight

# %%
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=25, interval=300, blit=True)

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### Simulation 6
# - Initially placed into 4 distinct groups
# - Probability of C: 0.4
# - Noise to location of offsprings: N(0,0.01)

# %%
PD6 = Simulation_PD(40, 200, bernoulli_arms, discounted_thompson, 50, False,0.4)
locs,loc_c,loc_d = PD6.plot_data_mult_gen(0.01)

# %%
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=50, interval=300, blit=True)

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Simulation 7
# - Initially placed randomly
# - Probability of C: 0.4
# - Noise to location of offsprings: N(0,0.1)

# %%
PD7 = Simulation_PD(40, 200, bernoulli_arms, discounted_thompson, 50, False,0.4)
locs,loc_c,loc_d = PD7.plot_data_mult_gen(0.1)

# %%
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=50, interval=300, blit=True)

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %% [markdown]
# Mutation to the location of an offspring: +N(0,0.1), 40% chance of being a cooperator initially, random initial location

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Simulation 8
# - Initially placed into 4 distinct groups
# - Probability of C: 0.8
# - Noise to location of offsprings: N(0,0.01)

# %%
PD8 = Simulation_PD(40, 200, bernoulli_arms, discounted_thompson, 50, True, 0.8)
locs,loc_c,loc_d = PD8.plot_data_mult_gen(0.01)

# %%
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=50, interval=300, blit=True)

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %% [markdown]
# Mutation to the location of an offspring: +N(0,0.1), 80% chance of being a cooperator initially, initial clustering in the corners of the $[0,1]^2$ box

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Simulation 9
# - Initially placed in 4 distinct groups
# - Probability of C: 1
# - Noise to location of offsprings: N(0,0.1)

# %%
PD9 = Simulation_PD(40, 200, bernoulli_arms, discounted_thompson, 50, True, 1.5)
locs,loc_c,loc_d = PD9.plot_data_mult_gen(0.1)

# %%
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=50, interval=300, blit=True)

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %% [markdown]
# Mutation to the location of an offspring: +N(0,0.1), 100% chance of being a cooperator initially, initial clustering in the corners of the $[0,1]^2$ box

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Simulation 10
# - Initially placed into 4 distinct groups
# - Probability of C: 1
# - Noise to location of offsprings: N(0,0.01)

# %%
PD10 = Simulation_PD(40, 200, bernoulli_arms, discounted_thompson, 50, True, 1.5)
locs,loc_c,loc_d = PD10.plot_data_mult_gen(0.01)

# %%
# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=50, interval=300, blit=True)

# %%
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# %% [markdown]
# Mutation to the location of an offspring: +N(0,0.01), 100% chance of being a cooperator initially, initial clustering in the corners of the $[0,1]^2$ box

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
