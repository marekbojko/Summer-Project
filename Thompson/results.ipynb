# %%
from evolving_comm_network import *

# %% [markdown]
# ## Initial embedding on a cycle

# %%
S = Simulation(40, 200, bernoulli_arms, discounted_thompson, const=False)

S.plot_data()
# Out:
# C:\Users\Marek\Documents\Summer Project\COde\Thompson\communication_network.py:419: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.node[j]['F'][s] += 1
# C:\Users\Marek\Documents\Summer Project\COde\Thompson\communication_network.py:417: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.node[j]['S'][s] += 1
# C:\Users\Marek\Anaconda3\lib\site-packages\numpy\core\_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %% [markdown]
# ## Constant initial propensity to share

# %%
MS = Multi_Sim(40, 200, bernoulli_arms, discounted_thompson, 3)

MS.plot_data()
# Out:
# C:\Users\Marek\Anaconda3\lib\site-packages\numpy\core\_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# C:\Users\Marek\Documents\Summer Project\COde\Thompson\communication_network.py:419: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.node[j]['F'][s] += 1
# C:\Users\Marek\Documents\Summer Project\COde\Thompson\communication_network.py:417: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.node[j]['S'][s] += 1
